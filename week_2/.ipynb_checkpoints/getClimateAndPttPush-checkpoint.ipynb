# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote
import time
import json

# %%
station_info = pd.read_csv('station_info.csv')

# %%
station_info
# Out:
#    Unnamed: 0                                             466880  \
# 0           0                                                 板橋
# 1           1                                            BANQIAO
# 2           2                                                新北市
# 3           3                     %25E6%259D%25BF%25E6%25A9%258B
# 4           4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466900  \
# 0                                                 淡水
# 1                                             TAMSUI
# 2                                                新北市
# 3                     %25E6%25B7%25A1%25E6%25B0%25B4
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466910  \
# 0                                                 鞍部
# 1                                               ANBU
# 2                                                臺北市
# 3                     %25E9%259E%258D%25E9%2583%25A8
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466920  \
# 0                                                 臺北
# 1                                             TAIPEI
# 2                                                臺北市
# 3                     %25E8%2587%25BA%25E5%258C%2597
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466930  \
# 0                                                竹子湖
# 1                                            ZHUZIHU
# 2                                                臺北市
# 3      %25E7%25AB%25B9%25E5%25AD%2590%25E6%25B9%2596
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466940  \
# 0                                                 基隆
# 1                                            KEELUNG
# 2                                                基隆市
# 3                     %25E5%259F%25BA%25E9%259A%2586
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466950  \
# 0                                                彭佳嶼
# 1                                          PENGJIAYU
# 2                                                基隆市
# 3      %25E5%25BD%25AD%25E4%25BD%25B3%25E5%25B6%25BC
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466990  \
# 0                                                 花蓮
# 1                                            HUALIEN
# 2                                                花蓮縣
# 3                     %25E8%258A%25B1%25E8%2593%25AE
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               467050  \
# 0                                                 新屋
# 1                                              XINWU
# 2                                                桃園市
# 3                     %25E6%2596%25B0%25E5%25B1%258B
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                               C1V600  \
# 0                                                 藤枝
# 1                                            Tengzhi
# 2                                                高雄市
# 3                     %25E8%2597%25A4%25E6%259E%259D
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1V780  \
# 0                                               多納林道
# 1                                        Duonalindao
# 2                                                高雄市
# 3  %25E5%25A4%259A%25E7%25B4%258D%25E6%259E%2597%...
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1X040  \
# 0                                                 東原
# 1                                           Dongyuan
# 2                                                臺南市
# 3                     %25E6%259D%25B1%25E5%258E%259F
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z030  \
# 0                                                 紅葉
# 1                                             Hongye
# 2                                                花蓮縣
# 3                     %25E7%25B4%2585%25E8%2591%2589
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z040  \
# 0                                                 立山
# 1                                             Lishan
# 2                                                花蓮縣
# 3                     %25E7%25AB%258B%25E5%25B1%25B1
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z110  \
# 0                                                 三棧
# 1                                            Sanzhan
# 2                                                花蓮縣
# 3                     %25E4%25B8%2589%25E6%25A3%25A7
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z120  \
# 0                                                 壽豐
# 1                                           Shoufeng
# 2                                                花蓮縣
# 3                     %25E5%25A3%25BD%25E8%25B1%2590
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z130  \
# 0                                                 銅門
# 1                                            Tongmen
# 2                                                花蓮縣
# 3                     %25E9%258A%2585%25E9%2596%2580
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z140  \
# 0                                                 荖溪
# 1                                              Laoxi
# 2                                                花蓮縣
# 3                     %25E8%258D%2596%25E6%25BA%25AA
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z240
# 0                                               中平林道
# 1                                    Zhongpinglindao
# 2                                                花蓮縣
# 3  %25E4%25B8%25AD%25E5%25B9%25B3%25E6%259E%2597%...
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
# [5 rows x 574 columns]

# %%
# axis = 1 (直行), axis = 2 (橫列), inplace = true(直接執行並且不返回結果) 
station_info.drop('Unnamed: 0',axis = 1)
# Out:
#                                               466880  \
# 0                                                 板橋
# 1                                            BANQIAO
# 2                                                新北市
# 3                     %25E6%259D%25BF%25E6%25A9%258B
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466900  \
# 0                                                 淡水
# 1                                             TAMSUI
# 2                                                新北市
# 3                     %25E6%25B7%25A1%25E6%25B0%25B4
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466910  \
# 0                                                 鞍部
# 1                                               ANBU
# 2                                                臺北市
# 3                     %25E9%259E%258D%25E9%2583%25A8
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466920  \
# 0                                                 臺北
# 1                                             TAIPEI
# 2                                                臺北市
# 3                     %25E8%2587%25BA%25E5%258C%2597
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466930  \
# 0                                                竹子湖
# 1                                            ZHUZIHU
# 2                                                臺北市
# 3      %25E7%25AB%25B9%25E5%25AD%2590%25E6%25B9%2596
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466940  \
# 0                                                 基隆
# 1                                            KEELUNG
# 2                                                基隆市
# 3                     %25E5%259F%25BA%25E9%259A%2586
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466950  \
# 0                                                彭佳嶼
# 1                                          PENGJIAYU
# 2                                                基隆市
# 3      %25E5%25BD%25AD%25E4%25BD%25B3%25E5%25B6%25BC
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               466990  \
# 0                                                 花蓮
# 1                                            HUALIEN
# 2                                                花蓮縣
# 3                     %25E8%258A%25B1%25E8%2593%25AE
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               467050  \
# 0                                                 新屋
# 1                                              XINWU
# 2                                                桃園市
# 3                     %25E6%2596%25B0%25E5%25B1%258B
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               467060  \
# 0                                                 蘇澳
# 1                                              SU-AO
# 2                                                宜蘭縣
# 3                     %25E8%2598%2587%25E6%25BE%25B3
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                               C1V600  \
# 0                                                 藤枝
# 1                                            Tengzhi
# 2                                                高雄市
# 3                     %25E8%2597%25A4%25E6%259E%259D
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1V780  \
# 0                                               多納林道
# 1                                        Duonalindao
# 2                                                高雄市
# 3  %25E5%25A4%259A%25E7%25B4%258D%25E6%259E%2597%...
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1X040  \
# 0                                                 東原
# 1                                           Dongyuan
# 2                                                臺南市
# 3                     %25E6%259D%25B1%25E5%258E%259F
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z030  \
# 0                                                 紅葉
# 1                                             Hongye
# 2                                                花蓮縣
# 3                     %25E7%25B4%2585%25E8%2591%2589
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z040  \
# 0                                                 立山
# 1                                             Lishan
# 2                                                花蓮縣
# 3                     %25E7%25AB%258B%25E5%25B1%25B1
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z110  \
# 0                                                 三棧
# 1                                            Sanzhan
# 2                                                花蓮縣
# 3                     %25E4%25B8%2589%25E6%25A3%25A7
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z120  \
# 0                                                 壽豐
# 1                                           Shoufeng
# 2                                                花蓮縣
# 3                     %25E5%25A3%25BD%25E8%25B1%2590
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z130  \
# 0                                                 銅門
# 1                                            Tongmen
# 2                                                花蓮縣
# 3                     %25E9%258A%2585%25E9%2596%2580
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z140  \
# 0                                                 荖溪
# 1                                              Laoxi
# 2                                                花蓮縣
# 3                     %25E8%258D%2596%25E6%25BA%25AA
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
#                                               C1Z240
# 0                                               中平林道
# 1                                    Zhongpinglindao
# 2                                                花蓮縣
# 3  %25E4%25B8%25AD%25E5%25B9%25B3%25E6%259E%2597%...
# 4  https://e-service.cwb.gov.tw/HistoryDataQuery/...
#
# [5 rows x 573 columns]

# %%
stationIndexList = station_info.columns

# %%
def getClimate(site,date,mode):
    
    precpAvgList = list()
    tempAvgList = list()
    
    #台-->臺
    if site[0] == '台':
        site = '臺'+site[1:] #字串無法直接指定, ex:site[k] = '臺'
            
    if mode == 1: 
        for i in range(len(stationIndexList)):       
            
            #此地區每個測站
            if station_info[stationIndexList[i]][2] == site:
                
                #需要delay才不會被擋
                time.sleep(0.11) 
                
                #去指定網址爬取
#                 print(station_info[stationIndexList[i]][4] + date) #網址
                temp=pd.read_html(station_info[stationIndexList[i]][4] + date)
                
                 #此測站24小時的資料
                for j in range(len(temp[1][10][2:])):
                    
                    #清空
                    precpList = list()
                    tempList = list() 
                    
                    #讀取，若是X則跳過
                    try:
                        precpList.append(np.float(temp[1][10][j+2]))
                        tempList.append(np.float(temp[1][3][j+2]))
                    except:
                        continue
                        
                    #求得此測站平均
                    precpAvg = np.average(precpList)
                    tempAvg = np.average(tempList)
                    
                #此地區所有測站值
                if precpAvg == precpAvg:  #確認是否為nan
                    precpAvgList.append(precpAvg)
                if tempAvg == tempAvg:
                    tempAvgList.append(tempAvg)
                    
        #算出所有測站平均回傳 
#         print(precpAvgList)
#         print(tempAvgList)
        
        return np.average(precpAvgList), np.average(tempAvgList)
    
    else:
        for i in range(len(stationIndexList)):
            
            #此地區每個人工測站
            if (station_info[stationIndexList[i]][2] == site) and stationIndexList[i].isdigit():
                
                #去指定網址爬取
#                 print(station_info[stationIndexList[i]][4] + date) #網址
                temp=pd.read_html(station_info[stationIndexList[i]][4] + date)
    
                 #此測站24小時的資料
                for j in range(len(temp[1][10][2:])):
                    #清空
                    precpList = list()
                    tempList = list() 
                    
                    #讀取，若是X則跳過
                    try:
                        precpList.append(np.float(temp[1][10][j+2]))
                        tempList.append(np.float(temp[1][3][j+2]))
                    except:
                        continue
                        
                    #求得此測站平均
                    precpAvg = np.average(precpList)
                    tempAvg = np.average(tempList)
                
                #此地區所有測站值
                if precpAvg == precpAvg:  #確認是否為nan
                    precpAvgList.append(precpAvg)
                if tempAvg == tempAvg:
                    tempAvgList.append(tempAvg)
#             else:
#                 break
        #算出人工測站平均回傳    
#         print(precpAvgList)
#         print(tempAvgList)
        return np.average(precpAvgList), np.average(tempAvgList)

# %%
getClimate('桃園市','2018-01-07',1)
# Out:
# (0.4428571428571429, 16.892307692307693)

# %%
getClimate('桃園市','2018-01-07',2)
# Out:
# (0.2, 17.6)

# %%
movies_info = pd.read_json("movie.json")

# %%
movies_info
# Out:
#              author   date push                                  title
# 0              ooic   9/24    1               [情報] 2018 北美10~12月上映電影列表
# 1      simplemurmur   9/24    0                   [好雷] 奇蹟男孩－內心堅強力量的善良。
# 2           sunnyee   9/24   31                              [負雷] 一屍到底
# 3           Beandou   9/24    6                [新聞] 《紅海行動》代表港出戰最佳外語片惹議
# 4         pttpttlin   9/24    0                [好雷] 《盲點》- 你能看見標籤的另一面嗎？
# 5       grimmm51764   9/24    3                   [問片] 一部美國警察追捕外國嫌犯的電影
# 6      riccardo1021   9/24    7                   [討論] 有什麼電影的政治正確過分誇張？
# 7         james2233   9/24   10                     [好雷]怪人雲集照樣幹大事-一屍到底
# 8                 -   9/24    0                    (本文已被刪除) [polo7551]
# 9             leila   9/24    1                 [好雷] 《失蹤網紅》-媽媽之間的羨慕與忌妒
# 10        lgng66133   9/24    1         [討論] Tommy Wiseau再度詮釋Joker!!!!
# 11       dreampiece   9/24    0                              [心得] 黃金兄弟
# 12          VOT1077   8/28    0                      [版規] 電影版版規 201808
# 18628       qweewqq   1/01   21               [新聞] 2018最受影迷期待的電影Top10！
# 18629         sindy   1/01   15                         [請益] 關於午夜巴黎結局？
# 18630     dogwang22   1/01    9                              [好無雷]大娛樂家
# 18631        qpr322   1/01    0                    [情報] 《戰狼2》台灣將直發 DVD
# 18632          boyo   1/01    5                          [討論] 2017票根通算
# 18633       rock810   1/01    4                      [討論] 模犯生的導演真的不懂嗎？
# 18634     pccu80825   1/01   11                       [請益] 與神同行的結局(有雷)
#
# [18635 rows x 4 columns]

# %%
movies_info.push.unique()
# Out:
# array(['1', '0', '31', '6', '3', '7', '10', '2', '24', '42', '30', '17',
#        '9', '18', '5', '84', '29', '75', '34', '8', '45', '13', '36',
#        '39', '15', '61', '26', '27', '14', '4', '53', '98', '38', '33',
#        '11', '87', '51', '12', '65', '23', '25', 'X2', '22', '35', '爆',
#        '37', '19', '48', '28', '85', '56', '20', '88', '46', '63', '16',
#        '40', '74', '43', '83', 'X1', '89', '71', '21', '64', '96', '94',
#        '99', '60', '49', '90', '52', '66', '57', '50', '70', '79', '97',
#        '76', '73', '54', '91', '69', '59', '82', '32', '41', '80', 'X5',
#        '58', '81', '67', '62', '72', '44', '68', '77', '55', '47', 'X8',
#        'XX', 'X6', '78', 'X4', '92', '93', 'X3', 'X7', 'X9', '95', '86'],
#       dtype=object)

# %%
movies_info.loc[movies_info["push"].str.match("爆"),"push"] = "100"
movies_info.loc[movies_info["push"].str.match("X1"),"push"] = "-10"
movies_info.loc[movies_info["push"].str.match("X2"),"push"] = "-20"
movies_info.loc[movies_info["push"].str.match("X3"),"push"] = "-30"
movies_info.loc[movies_info["push"].str.match("X4"),"push"] = "-40"
movies_info.loc[movies_info["push"].str.match("X5"),"push"] = "-50"
movies_info.loc[movies_info["push"].str.match("X6"),"push"] = "-60"
movies_info.loc[movies_info["push"].str.match("X7"),"push"] = "-70"
movies_info.loc[movies_info["push"].str.match("X8"),"push"] = "-80"
movies_info.loc[movies_info["push"].str.match("X9"),"push"] = "-90"
movies_info.loc[movies_info["push"].str.match("XX"),"push"] = "-100"

# %%
movies_info['push'] = movies_info['push'].astype(str).astype(int)
movies_info.push.unique()
# Out:
# array([   1,    0,   31,    6,    3,    7,   10,    2,   24,   42,   30,
#          17,    9,   18,    5,   84,   29,   75,   34,    8,   45,   13,
#          36,   39,   15,   61,   26,   27,   14,    4,   53,   98,   38,
#          33,   11,   87,   51,   12,   65,   23,   25,  -20,   22,   35,
#         100,   37,   19,   48,   28,   85,   56,   20,   88,   46,   63,
#          16,   40,   74,   43,   83,  -10,   89,   71,   21,   64,   96,
#          94,   99,   60,   49,   90,   52,   66,   57,   50,   70,   79,
#          97,   76,   73,   54,   91,   69,   59,   82,   32,   41,   80,
#         -50,   58,   81,   67,   62,   72,   44,   68,   77,   55,   47,
#         -80, -100,  -60,   78,  -40,   92,   93,  -30,  -70,  -90,   95,
#          86])

# %%
movie_push = movies_info.groupby("date", as_index=False).sum()

# %%
movie_push.loc[movie_push["date"].str.match("12/31")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-466b1a099ae2> in <module>()
# ----> 1 del movie_push.loc[movie_push["date"].str.match("12/31")]
#
# AttributeError: __delitem__
